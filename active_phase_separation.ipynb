# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import log as ln, cumsum
from scipy.integrate import simpson

plt.rc("font", family="serif", size=16)
plt.rc("mathtext", fontset="cm")
plt.rc("lines", lw=2)

# %%
x0 = 0.00001
x1 = 8
N = 1000
x = np.linspace(x0, x1, N)

plt.plot(x, x*(ln(x) - 1),'k')

# %%
x0 = 0.00001
x1 = 8
N = 1000
dx = (x1 - x0) / N
x = np.linspace(x0, x1, N)

aa = [0, 0.05, .1, .2, .3, .4, .5]
b = 4
for a in aa:
    v = lambda r : b - a*x
    f = lambda r : v(r)

    plt.plot(x, f(x),'k')

# %%
x0 = 0.00001
x1 = 8
N = 1000
dx = (x1 - x0) / N
x = np.linspace(x0, x1, N)

aa = [0, 0.05, .1, .2, .3, .4, .5]
b = 1
for a in aa:
    v = lambda r : b - a*x
    f = lambda r : ln(v(r))

    plt.plot(x, f(x),'k')
# Out:
# /tmp/ipykernel_578146/817854223.py:11: RuntimeWarning: invalid value encountered in log
#   f = lambda r : ln(v(r))
# /tmp/ipykernel_578146/817854223.py:11: RuntimeWarning: invalid value encountered in log
#   f = lambda r : ln(v(r))
# /tmp/ipykernel_578146/817854223.py:11: RuntimeWarning: invalid value encountered in log
#   f = lambda r : ln(v(r))
# /tmp/ipykernel_578146/817854223.py:11: RuntimeWarning: invalid value encountered in log
#   f = lambda r : ln(v(r))

# %%
x0 = 0.00001
x1 = 10
N = 1000
dx = (x1 - x0) / N
x = np.linspace(x0, x1, N)
a = -.2

v = lambda r : 1 + a*x
f = lambda r : r * (ln(r) - 1) - r + (1 / a + r) * ln(1+ a *x)
f = lambda r : r * (ln(r) - 1) + np.cumsum(ln(v(r))) * dx

def integrate(v, a, b):
    x = np.linspace(a, b, 1000)
    dx = (b - a)/1000
    return np.sum(v(x)) * dx

plt.plot(x, f(x),'k')
# Out:
# /tmp/ipykernel_578146/1255047840.py:10: RuntimeWarning: invalid value encountered in log
#   f = lambda r : r * (ln(r) - 1) + np.cumsum(ln(v(r))) * dx

# %%
x = np.linspace(0, 8, 100)
plt.plot(x, ln(v(x)))
plt.plot(x, simpson(ln(v(np.linspace(0, x, 1000)), np.linspace(0, x, 1000))))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_549703/927480241.py in <module>
#       1 x = np.linspace(0, 8, 100)
#       2 plt.plot(x, ln(v(x)))
# ----> 3 plt.plot(x, simpson(ln(v(np.linspace(0, x, 1000)), np.linspace(0, x, 1000))))
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...
